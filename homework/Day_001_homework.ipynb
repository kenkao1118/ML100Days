# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):

    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    mse = MSE = sum(np.power((y-yp),2))/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 250.334
# The Mean absolute error is 12.595

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# I choice this dataset is "Predict survival on thee Titanic and get familiar with ML basics", why i choice this topic. due to it's the best, first challenge for me to dive into ML competitions and dfamiliarize kaggle platform works.
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 此資料是由Kaggle提供的,他的資料主要是整理鐵達尼號的所有乘客的相關歷史資料,包括性別,兄弟姊妹,父母/子女數與乘坐的艙別...等.
# 3. 蒐集而來的資料型態為何
# 資料型態主要有字串如姓名,性別,船票號碼與登船地點,整數如旅客編號,是否存活,艙別,年齡,兄弟姊妹個數..等,浮點數如船票價格.
# 4. 這組資料想解決的問題如何評估
# 由於此資料是用來預測存活率,我覺得可以從以下幾個因素來做特徵資料分析,第一是年齡,因為最後在船撞上冰山後,準備乘上救難艇,則會優先考慮兒童與老人.第二個部分要考慮的則是性別,因為在存活率上我想婦女會比男人有更高的優先權能先乘上救難艇,第三則是是Sibsp也就是兄弟姊妹與配偶數,從存活率來看的話,兄弟姊妹越少的相對於存活率也會越高,第四則是可以加入Parch來分析,由資料中可以看出,當有跟著大人一起的,存活率也會相對更高.第五個則可以從Ticket與Cabin來做資料預測.
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我會將提升業績定義為提升載客率與減少空車在固定地點的等待時間.
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 交通部的計程車營運狀況報告(105-108) , 台北市計程車營運概況報告
# 3. 蒐集而來的資料型態為何
# 資料內容含括駕駛人年齡,學歷,車型(新/二手),個人車或車行,排氣量,載客模式(招攬,定點,派車..),車齡,北中南各地區的時間空車率與距離空車率,
# 駕駛年資,駕駛所在的工作區域,駕駛每天的營業時數,載客數,營收,是否有加入APP叫車服務.....
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 1.先分析目前收集到的相關資料來做分析,並將這些資料做整理來取出80%做訓練資料,20%做測試資料.
# 2.並先將此AI model完成.
# 3.將現在或之前自由載客車隊的資料,當作驗證資料來讓AI model做驗證,看是否能成功預測出載客數,
# 營收,趟數,然後與ground true做比較確認此model是否準確.
# 4.如果是準確的則就可以使用此AI model來改善載客數與營收.
